# %%
# !pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.21.6)

# %%
import numpy as np

# %%
array = np.array([1,2,3,4,5])

# %%
print(type(array))
# Out:
# <class 'numpy.ndarray'>

# %%
revenues = [2000,5000,3000,6500,7200,3100,2650,1900,3820,5120,4100]

# %%
import time

# %%
initial_time = time.time()
sum = 0

# %%
for i in revenues:
  sum += i
print(sum)
termination_time = time.time()
 
print("Execution Time: ",termination_time-initial_time)
# Out:
# 88780
# Execution Time:  5.069233179092407

# %%
array = np.array(revenues)
 
initial_time = time.time()
 
sum = array.sum()
print(sum)
termination_time = time.time()
 
print("Execution Time: ",termination_time-initial_time)
# Out:
# 44390
# Execution Time:  0.00019073486328125

# %%
x = ['Ben',500,'Jake','Liz',6000]
print(x)
# Out:
# ['Ben', 500, 'Jake', 'Liz', 6000]

# %%
for i in x:
  print(type(i))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'str'>
# <class 'str'>
# <class 'int'>

# %%
arrayx = np.array(x)
print(arrayx)
# Out:
# ['Ben' '500' 'Jake' 'Liz' '6000']

# %%
for i in arrayx:
  print(type(i))
# Out:
# <class 'numpy.str_'>
# <class 'numpy.str_'>
# <class 'numpy.str_'>
# <class 'numpy.str_'>
# <class 'numpy.str_'>

# %%
array2  = np.array([[1, 2, 3], [4, 5, 6]])

# %%
print(array2)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
array2.ndim
# Out:
# 2

# %%
array2.shape
# Out:
# (2, 3)

# %%
array2.size
# Out:
# 6
